# %% [markdown]
# # List and Tuples
# <hr style="border: 1px solid #b9338dff;">

# %% [markdown]
# <b>Desiree Valois</b>
# <br>Computer Engineer

# %% [markdown]
# ## Creating a list

# %%
numbers = [1, 2, 3, 4, 5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ['apple', 'banana', 'grape']

# %%
mixed_list = [10, "hello", 2.5, True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# ## Indexing

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 3

# %% [markdown]
# ## Modifying Elements

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
fruits[-2] = 'kiwi'
fruits
# Out:
# ['orange', 'kiwi', 'grape']

# %% [markdown]
# ## Adding Elements

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits.append('mango')
fruits
# Out:
# ['apple', 'banana', 'grape', 'mango']

# %%
fruits.insert(1, 'orange')
fruits
# Out:
# ['apple', 'orange', 'banana', 'grape', 'mango']

# %% [markdown]
# ## Removing Elements

# %%
fruits = ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'avocado' in fruits
# Out:
# False

# %%
fruits.remove('banana')
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grape']

# %% [markdown]
# ## sort() and sorted()

# %%
numbers = [3, 1, 2, 5, 4]
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Slicing

# %%
numbers = [3, 5, 7, 2, 1, 4, 6, 8, 9, 11, 10]
numbers
# Out:
# [3, 5, 7, 2, 1, 4, 6, 8, 9, 11, 10]

# %%
len(numbers)
# Out:
# 11

# %%
numbers[1:5]
# Out:
# [5, 7, 2, 1]

# %%
sub = numbers[1:5]
sub
# Out:
# [5, 7, 2, 1]

# %%
numbers[0:8:2]
# Out:
# [3, 7, 1, 6]

# %% [markdown]
# ## Tuples

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple = my_tuple[:1] + (1,) + my_tuple[2:]
print(my_tuple)
# Out:
# (1, 1, 3, 4, 5)
